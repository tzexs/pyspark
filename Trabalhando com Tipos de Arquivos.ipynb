# %% [markdown]
# <h1> Importação das Bibliotecas </h1>

# %%
import os
os.environ["SPARK_HOME"] = "/home/thiagosantos/spark/spark-3.4.1-bin-hadoop3"

# %%
import findspark
findspark.init()

# %% [markdown]
# <h1> Iniciando Sessão Spark </h1>

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# <h2> Solicitando criação ou utilização do Spark com todos os nódulos de computação local </h2>

# %%
spark = SparkSession.builder.master('local[*]').getOrCreate()
# Out:
# 23/07/23 16:14:22 WARN Utils: Your hostname, Ubuntu-do-Tze resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 23/07/23 16:14:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/07/23 16:14:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# <h3> Ensinando como juntar dados de colunas </h3>

# %%
data = [('Zeca', '35'), ('Eva', '29')]
colNames = ['Nome', 'Idade']
df = spark.createDataFrame(data,colNames)
df
# Out:
# DataFrame[Nome: string, Idade: string]

# %%
df.show()
# Out:
# +----+-----+
# |Nome|Idade|
# +----+-----+
# |Zeca|   35|
# | Eva|   29|
# +----+-----+

# %% [markdown]
# <h3> Importando zipfile </h3>

# %%
#Zipfile é uma função para descompactação de arquivos zip
import zipfile

# %% [markdown]
# <h3> Descompactando os zips de Empresas, Estabelecimentos e Sócios </h3>

# %%
#zipfile.ZipFile('/home/thiagosantos/Curso-Spark/empresas.zip', 'r').extractall('/home/thiagosantos/Curso-Spark/')
#zipfile.ZipFile('/home/thiagosantos/Curso-Spark/estabelecimentos.zip', 'r').extractall('/home/thiagosantos/Curso-Spark/')
#zipfile.ZipFile('/home/thiagosantos/Curso-Spark/socios.zip', 'r').extractall('/home/thiagosantos/Curso-Spark/')

# %% [markdown]
# <h3> Lendo todos os registros de empresa </h3>

# %%
path_empresa = '/home/thiagosantos/Curso-Spark/empresas'
empresas = spark.read.csv(path_empresa, sep=';', inferSchema=True)
empresas.count()
# Out:
# 4585679

# %% [markdown]
# <h3> Lendo todos os registros dos estabelecimentos </h3>

# %%
path_estabelecimentos = '/home/thiagosantos/Curso-Spark/estabelecimentos'
estabelecimentos = spark.read.csv(path_estabelecimentos, sep=';', inferSchema=True)

# %% [markdown]
# <h3> Lendo todos os registros dos sócios </h3>

# %%
path_socios = '/home/thiagosantos/Curso-Spark/socios'
socios = spark.read.csv(path_socios, sep=';', inferSchema=True)

# %%
#empresas.limit(5).toPandas()
#estabelecimentos.limit(5).toPandas()
socios.limit(5).toPandas()
# Out:
#      _c0  _c1                              _c2          _c3  _c4       _c5  \
# 0    411    2      LILIANA PATRICIA GUASTAVINO  ***678188**   22  19940725
# 1    411    2             CRISTINA HUNDERTMARK  ***637848**   28  19940725
# 2   5813    2  CELSO EDUARDO DE CASTRO STEPHAN  ***786068**   49  19940516
# 3   5813    2        EDUARDO BERRINGER STEPHAN  ***442348**   49  19940516
# 4  14798    2              HANNE MAHFOUD FADEL  ***760388**   49  19940609
#
#    _c6          _c7   _c8  _c9  _c10
# 0  NaN  ***000000**  None    0     7
# 1  NaN  ***000000**  None    0     7
# 2  NaN  ***000000**  None    0     8
# 3  NaN  ***000000**  None    0     5
# 4  NaN  ***000000**  None    0     8

# %% [markdown]
# <h3> Dando nome às colunas </h3>

# %%
empresasColNames = ['cnpj_basico', 'razao_social_nome_empresarial', 'natureza_juridica', 'qualificacao_do_responsavel', 'capital_social_da_empresa', 'porte_da_empresa', 'ente_federativo_responsavel']
estabsColNames = ['cnpj_basico', 'cnpj_ordem', 'cnpj_dv', 'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral', 'motivo_situacao_cadastral', 'nome_da_cidade_no_exterior', 'pais', 'data_de_inicio_atividade', 'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'tipo_de_logradouro', 'logradouro', 'numero', 'complemento', 'bairro', 'cep', 'uf', 'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2', 'ddd_do_fax', 'fax', 'correio_eletronico', 'situacao_especial', 'data_da_situacao_especial']
sociosColNames = ['cnpj_basico', 'identificador_de_socio', 'nome_do_socio_ou_razao_social', 'cnpj_ou_cpf_do_socio', 'qualificacao_do_socio', 'data_de_entrada_sociedade', 'pais', 'representante_legal', 'nome_do_representante', 'qualificacao_do_representante_legal', 'faixa_etaria']

# %%
for index, colName in enumerate(empresasColNames):
    empresas = empresas.withColumnRenamed(f"_c{index}", colName)

empresas.columns
# Out:
# ['cnpj_basico',
#  'razao_social_nome_empresarial',
#  'natureza_juridica',
#  'qualificacao_do_responsavel',
#  'capital_social_da_empresa',
#  'porte_da_empresa',
#  'ente_federativo_responsavel']

# %%
for index, colName in enumerate(estabsColNames):
    estabelecimentos = estabelecimentos.withColumnRenamed(f"_c{index}", colName)

empresas.columns
# Out:
# ['cnpj_basico',
#  'razao_social_nome_empresarial',
#  'natureza_juridica',
#  'qualificacao_do_responsavel',
#  'capital_social_da_empresa',
#  'porte_da_empresa',
#  'ente_federativo_responsavel']

# %%
for index, colName in enumerate(sociosColNames):
    socios = socios.withColumnRenamed(f"_c{index}", colName)

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
estabelecimentos.limit(5).toPandas()
# Out:
# 23/07/23 02:56:04 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
# ...

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: integer (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: integer (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: integer (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %% [markdown]
# <h3> Importando diferentes data types e funções SQL </H3>

# %%
from pyspark.sql.types import DoubleType, StringType
from pyspark.sql import functions as f

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %% [markdown]
# <h3> Tratando valores </h3>

# %%
empresas = empresas.withColumn('capital_social_da_empresa', f.regexp_replace('capital_social_da_empresa', ',', '.'))
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0.00
# 1               2062                           49                      0.00
# 2               3034                           32                      0.00
# 3               2135                           50                      0.00
# 4               2062                           49                   4000.00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas = empresas.withColumn('capital_social_da_empresa', empresas['capital_social_da_empresa'].cast(DoubleType()))

# %% [markdown]
# <h3> Tratando Type Date </h3>

# %%
df = spark.createDataFrame([(20200924,), (20201022,), (20210215,)], ['data'])
df.toPandas()
# Out:
#        data
# 0  20200924
# 1  20201022
# 2  20210215

# %%
df.printSchema()
# Out:
# root
#  |-- data: long (nullable = true)

# %%
df = df.withColumn("data", f.to_date(df.data.cast(StringType()), 'yyyyMMdd'))
df.printSchema()
# Out:
# root
#  |-- data: date (nullable = true)

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: integer (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: integer (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %% [markdown]
# <h3> Tratando coluna data_situacao_cadastral </h3>

# %%
estabelecimentos = estabelecimentos\
    .withColumn(
        "data_situacao_cadastral",
        f.to_date(estabelecimentos.data_situacao_cadastral.cast(StringType()), 'yyyyMMdd')
    )

# %%
estabelecimentos = estabelecimentos\
    .withColumn(
        "data_situacao_cadastral",
        f.to_date(estabelecimentos.data_de_inicio_atividade.cast(StringType()), 'yyyyMMdd')
    )

# %%
estabelecimentos = estabelecimentos\
    .withColumn(
        "data_situacao_cadastral",
        f.to_date(estabelecimentos.data_da_situacao_especial.cast(StringType()), 'yyyyMMdd')
    )

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
socios = socios\
    .withColumn(
        "data_de_entrada_sociedade",
        f.to_date(socios.data_de_entrada_sociedade.cast(StringType()), 'yyyyMMdd')
    )

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %% [markdown]
# <h3> Usando SparkSQL </h3>

# %%
empresas\
    .select('*')\
    .show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
empresas\
    .select('natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
    .show(5)
# Out:
# +-----------------+----------------+-------------------------+
# |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +-----------------+----------------+-------------------------+
# |             2240|               1|                      0.0|
# |             2062|               5|                      0.0|
# |             3034|               5|                      0.0|
# |             2135|               5|                      0.0|
# |             2062|               1|                   4000.0|
# +-----------------+----------------+-------------------------+
# only showing top 5 rows

# %%
socios\
    .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .orderBy(['ano_de_entrada', 'faixa_etaria'], ascending=[False, False])\
    .show(10,False)
# Out:
# [Stage 12:==============================================>           (4 + 1) / 5]
# +-------------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social        |faixa_etaria|ano_de_entrada|
# +-------------------------------------+------------+--------------+
# |MARIA LUCIA GOMES LOMBA              |9           |2021          |
# |LUZINETE DANTAS DE OLIVEIRA RODRIGUES|9           |2021          |
# |MARIA RAIMUNDA DOS SANTOS LANZA      |9           |2021          |
# |JOAO KOJIN                           |9           |2021          |
# |UMBERTO BASTOS SACCHELLI             |9           |2021          |
# |FERNANDO MARCONDES DE MATTOS         |9           |2021          |
# |RENILDE DAS GRACAS MAIA              |9           |2021          |
# |YARA CABRAL PINTO                    |9           |2021          |
# |FRANCISCO PIMPINATO                  |9           |2021          |
# |JOSE CURADO ADORNO                   |9           |2021          |
# ...

# %%
estabelecimentos = estabelecimentos\
    .withColumn(
        "data_de_inicio_atividade",
        f.to_date(estabelecimentos.data_de_inicio_atividade.cast(StringType()), 'yyyyMMdd')
    )

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
estabelecimentos\
    .select('nome_fantasia', 'municipio', f.year('data_de_inicio_atividade').alias('ano_de_inicio_atividade'), f.month('data_de_inicio_atividade').alias('mes_de_inicio_atividade'))\
    .show(5)
# Out:
# +-----------------+---------+-----------------------+-----------------------+
# |    nome_fantasia|municipio|ano_de_inicio_atividade|mes_de_inicio_atividade|
# +-----------------+---------+-----------------------+-----------------------+
# |   PIRAMIDE M. C.|     7107|                   1994|                      5|
# |             null|     7107|                   1994|                      5|
# |             null|     7107|                   1994|                      5|
# |             null|     7107|                   1994|                      5|
# |EMBROIDERY & GIFT|     7075|                   1995|                      5|
# +-----------------+---------+-----------------------+-----------------------+
# only showing top 5 rows

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
df = spark.createDataFrame([(1,), (2,), (3,), (None,)], ['data'])
df.toPandas()
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
df.show()
# Out:
# +----+
# |data|
# +----+
# |   1|
# |   2|
# |   3|
# |null|
# +----+

# %%
df = spark.createDataFrame([(1.,), (2.,), (3.,), (float('nan'),)], ['data'])
df.toPandas()
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
df = spark.createDataFrame([('1',), ('2',), ('3',), (None,)], ['data'])
df.toPandas()
# Out:
#    data
# 0     1
# 1     2
# 2     3
# 3  None

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |        411|                     2|         LILIANA PATRICIA ...|         ***678188**|                   22|               1994-07-25|null|        ***000000**|                 null|                                  0|           7|
# ...

# %%
#contagem de valores nulos por coluna
socios.select([f.count(f.when(f.isnull(c), 1)).alias(c) for c in socios.columns]).show()
# Out:
# [Stage 18:==============================================>           (4 + 1) / 5]
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|   pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# ...

# %%
socios.na.fill(0).limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25     0
# 1          ***637848**                     28                1994-07-25     0
# 2          ***786068**                     49                1994-05-16     0
# 3          ***442348**                     49                1994-05-16     0
# 4          ***760388**                     49                1994-06-09     0
#
#   representante_legal nome_do_representante  \
# ...

# %%
empresas\
    .filter("capital_social_da_empresa == 50")\
    .show(5,False)
# Out:
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial       |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |17350147   |ERIK MARCELO DOS SANTOS 42107848858 |2135             |50                         |50.0                     |1               |null                       |
# |17833214   |ALEXANDRE MACHADO LIMA 73750123772  |2135             |50                         |50.0                     |1               |null                       |
# ...

# %%
socios\
    .select("nome_do_socio_ou_razao_social")\
    .filter(socios.nome_do_socio_ou_razao_social.startswith("THIAGO"))\
    .filter(socios.nome_do_socio_ou_razao_social.endswith("SANTOS"))\
    .limit(60)\
    .toPandas()
# Out:
#                 nome_do_socio_ou_razao_social
# 0                     THIAGO SOUSA DOS SANTOS
# 1                        THIAGO CORREA SANTOS
# 2                   THIAGO PEREIRA DOS SANTOS
# 3            THIAGO TAKHOS ALENCAR DOS SANTOS
# 4                  THIAGO HENRIQUE DOS SANTOS
# 5                THIAGO TRASPADINI DOS SANTOS
# 6                   THIAGO DE OLIVEIRA SANTOS
# 7             THIAGO JOSE TEIXEIRA DOS SANTOS
# 8                         THIAGO PEREZ SANTOS
# 9                     THIAGO LEITE DOS SANTOS
# 10              THIAGO SILVA DE MORAES SANTOS
# 11                THIAGO RODRIGO SILVA SANTOS
# 12                  THIAGO PEREIRA DOS SANTOS
# 13                  THIAGO PEREIRA DOS SANTOS
# 14                THIAGO RODRIGUES DOS SANTOS
# 15                  THIAGO CARDOSO DOS SANTOS
# 16           THIAGO DA SILVA ALVES DOS SANTOS
# 17  THIAGO ANTONIO MACIEL CORDEIRO DOS SANTOS
# 18                    THIAGO CUTER DOS SANTOS
# ...

# %%
df = spark.createDataFrame([('RESTAURANTE DO RUI',), ('Juca restaurantes ltda',), ('Joca Restaurante',)], ['data'])
df.toPandas()
# Out:
#                      data
# 0      RESTAURANTE DO RUI
# 1  Juca restaurantes ltda
# 2        Joca Restaurante

# %%
df\
    .where(f.upper(df.data).like('RESTAURANTE%'))\
    .show()
# Out:
# +------------------+
# |              data|
# +------------------+
# |RESTAURANTE DO RUI|
# +------------------+

# %%
empresas\
    .select('razao_social_nome_empresarial', 'natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
    .filter(f.upper(empresas['razao_social_nome_empresarial']).like('%RESTAURANTE%'))\
    .show(15, False)
# Out:
# +-------------------------------------------------------+-----------------+----------------+-------------------------+
# |razao_social_nome_empresarial                          |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +-------------------------------------------------------+-----------------+----------------+-------------------------+
# |RESTAURANTE IMIGRANTE PORTUGUES LTDA.                  |2062             |5               |0.0                      |
# |MORAIS & CARVALHO RESTAURANTE E PIZZARIA LTDA          |2062             |1               |0.0                      |
# |BAR E RESTAURANTE PAGANOTTO LTDA                       |2062             |5               |0.0                      |
# |RODRIGUES & RODRIGUES RESTAURANTE LTDA                 |2062             |5               |0.0                      |
# |TEXAS RANCH BAR RESTAURANTE PRODUCOES ARTISTICAS E CULT|2062             |1               |0.0                      |
# ...

# %%
socios\
    .select(f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .where('ano_de_entrada >= 2010')\
    .groupBy('ano_de_entrada')\
    .count()\
    .orderBy('ano_de_entrada', ascending = True)\
    .show()
# Out:
# [Stage 35:==============================================>           (4 + 1) / 5]
# +--------------+------+
# |ano_de_entrada| count|
# +--------------+------+
# |          2010| 79337|
# |          2011| 83906|
# |          2012| 80101|
# |          2013| 83919|
# |          2014| 80590|
# |          2015| 80906|
# |          2016| 81587|
# |          2017| 90221|
# |          2018| 99935|
# |          2019|118248|
# |          2020|125927|
# |          2021| 56316|
# +--------------+------+

# %%
empresas\
    .select('cnpj_basico', 'porte_da_empresa', 'capital_social_da_empresa')\
    .groupBy('porte_da_empresa')\
    .agg(
        f.avg("capital_social_da_empresa").alias("capital_social_medio"),
        f.count("cnpj_basico").alias("frequencia")
    )\
    .orderBy('porte_da_empresa', ascending = True)\
    .show()
# Out:
# [Stage 39:==============================================>           (4 + 1) / 5]
# +----------------+--------------------+----------+
# |porte_da_empresa|capital_social_medio|frequencia|
# +----------------+--------------------+----------+
# |            null|    8.35421888053467|      5985|
# |               1|  339994.53313507006|   3129043|
# |               3|   2601001.767709269|    115151|
# |               5|   708660.4208249792|   1335500|
# +----------------+--------------------+----------+

# %%
empresas\
    .select("capital_social_da_empresa")\
    .summary()\
    .show()
# Out:
# [Stage 42:==============================================>           (4 + 1) / 5]
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542677|
# | stddev|      2.111869149053794E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %%
empresas_join = estabelecimentos.join(empresas, 'cnpj_basico', how='inner')

# %%
empresas_join.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
freq = empresas_join\
    .select(
        'cnpj_basico',
        f.year('data_de_inicio_atividade').alias('data_de_inicio')
    )\
    .where('data_de_inicio >= 2010')\
    .groupBy('data_de_inicio')\
    .agg(f.count("cnpj_basico").alias("frequencia"))\
    .orderBy('data_de_inicio', ascending=True)

# %%
freq.toPandas()
# Out:
# 23/07/23 17:19:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 17:19:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 17:19:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 17:19:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
#     data_de_inicio  frequencia
# 0             2010      154159
# 1             2011      172677
# 2             2012      232480
# 3             2013      198424
# 4             2014      202276
# 5             2015      212523
# 6             2016      265417
# 7             2017      237292
# 8             2018      275435
# 9             2019      325922
# 10            2020      400654
# 11            2021      153275

# %%
freq.union(
    freq.select(
        f.lit('Total').alias('data_de_inicio'),
        f.sum(freq.frequencia).alias('frequencia')

    )
).show()
# Out:
# 23/07/23 17:31:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 17:31:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 17:31:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 17:31:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +--------------+----------+
# |data_de_inicio|frequencia|
# +--------------+----------+
# |          2010|    154159|
# |          2011|    172677|
# |          2012|    232480|
# |          2013|    198424|
# |          2014|    202276|
# |          2015|    212523|
# |          2016|    265417|
# |          2017|    237292|
# |          2018|    275435|
# |          2019|    325922|
# |          2020|    400654|
# |          2021|    153275|
# |         Total|   2830534|
# +--------------+----------+

# %%
empresas.createOrReplaceTempView("empresasView")

# %%
spark.sql("SELECT * FROM empresasView").show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
spark\
    .sql("""
        SELECT porte_da_empresa, MEAN(capital_social_da_empresa) AS Media
            FROM empresasView
            GROUP BY porte_da_empresa    
""")\
.show(5)
# Out:
# [Stage 90:==============================================>           (4 + 1) / 5]
# +----------------+------------------+
# |porte_da_empresa|             Media|
# +----------------+------------------+
# |            null|  8.35421888053467|
# |               1|339994.53313507006|
# |               3| 2601001.767709269|
# |               5| 708660.4208249792|
# +----------------+------------------+

# %%
empresas_join.createOrReplaceTempView("empresasJoinView")
# Out:
# 23/07/23 18:02:28 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
freq = spark\
    .sql("""
         SELECT YEAR(data_de_inicio_atividade) AS data_de_inicio, COUNT(cnpj_basico) AS count
            FROM empresasJoinView
            WHERE YEAR(data_de_inicio_atividade) >= 2010
            GROUP BY data_de_inicio
            ORDER BY data_de_inicio
         """)

freq\
    .show()
# Out:
# 23/07/23 18:20:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 18:20:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 18:20:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 18:20:55 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 106:==========================================>              (3 + 1) / 4]
# +--------------+------+
# |data_de_inicio| count|
# +--------------+------+
# |          2010|154159|
# |          2011|172677|
# |          2012|232480|
# |          2013|198424|
# |          2014|202276|
# |          2015|212523|
# |          2016|265417|
# |          2017|237292|
# |          2018|275435|
# |          2019|325922|
# |          2020|400654|
# |          2021|153275|
# +--------------+------+

# %%
freq.createOrReplaceTempView("freqView")

# %%
spark\
    .sql("""
        SELECT *
            FROM freqView
        UNION ALL
        SELECT 'Total' AS data_de_inicio, SUM(count) AS count
            FROM freqView
    """)\
    .show()
# Out:
# 23/07/23 18:23:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 18:23:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 18:23:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/07/23 18:23:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +--------------+-------+
# |data_de_inicio|  count|
# +--------------+-------+
# |          2010| 154159|
# |          2011| 172677|
# |          2012| 232480|
# |          2013| 198424|
# |          2014| 202276|
# |          2015| 212523|
# |          2016| 265417|
# |          2017| 237292|
# |          2018| 275435|
# |          2019| 325922|
# |          2020| 400654|
# |          2021| 153275|
# |         Total|2830534|
# +--------------+-------+

# %%
empresas.write.csv(
    path = "/home/thiagosantos/Curso-Spark/empresas/csv",
    mode = 'overwrite',
    sep = ';',
    header=True
)

# %%
estabelecimentos.write.csv(
    path = "/home/thiagosantos/Curso-Spark/estabelecimentos/csv",
    mode = 'overwrite',
    sep = ';',
    header=True
)

# %%
socios.write.csv(
    path = "/home/thiagosantos/Curso-Spark/socios/csv",
    mode = 'overwrite',
    sep = ';',
    header=True
)

# %%
empresas2 = spark.read.csv(
    "/home/thiagosantos/Curso-Spark/empresas/csv",
    sep = ';',
    inferSchema = True,
    header=True

)

# %%
estabelecimentos2 = spark.read.csv(
    "/home/thiagosantos/Curso-Spark/estabelecimentos/csv",
    sep = ';',
    inferSchema = True,
    header=True
)

# %%
socios2 = spark.read.csv(
    "/home/thiagosantos/Curso-Spark/socios/csv",
    sep = ';',
    inferSchema = True,
    header=True
)

# %%
empresas.write.parquet(
    path = "/home/thiagosantos/Curso-Spark/empresas/parquet",
    mode = 'overwrite'

)

# %%
empresas.write.orc(
    path = "/home/thiagosantos/Curso-Spark/empresas/orc",
    mode = 'overwrite'

)

# %%
empresas_orc = spark.read.orc(
    "/home/thiagosantos/Curso-Spark/empresas/orc"
    
)

# %%
empresas_parquet = spark.read.parquet(
    "/home/thiagosantos/Curso-Spark/empresas/parquet"
    
)

# %%
empresas_parquet.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
# F = f
date_cols = [item[0] for item in estabelecimentos.dtypes if item[1].startswith('date')]
for date_col in date_cols:
    estabelecimentos = estabelecimentos.withColumn(date_col, 
    f.when(
      f.col(date_col) <= '1900-01-01', 
      f.to_date(f.lit('1900-01-01'), 'yyyy-MM-dd'))
    .otherwise(f.col(date_col)))

# %%
estabelecimentos.write.parquet(
    path = "/home/thiagosantos/Curso-Spark/estabelecimentos/parquet",
    mode = 'overwrite'
)

# %%
estabelecimentos_parquet = spark.read.parquet(
    "/home/thiagosantos/Curso-Spark/estabelecimentos/parquet"
    
)

# %%
socios.write.parquet(
    path = "/home/thiagosantos/Curso-Spark/socios/parquet",
    mode = 'overwrite'
)

# %%
socios_parquet = spark.read.parquet(
    "/home/thiagosantos/Curso-Spark/socios/parquet"
    
)

# %%
empresas.coalesce(1).write.csv(
    path = "/home/thiagosantos/Curso-Spark/empresas/csv-unico",
    mode = 'overwrite',
    sep =';',
    header=True

)

# %%
empresas.write.parquet(
    path = "/home/thiagosantos/Curso-Spark/empresas/parquet-partitionBy",
    mode = 'overwrite',
    partitionBy='porte_da_empresa'

)

# %%
spark.stop()
